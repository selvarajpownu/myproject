# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras import Model
from keras.layers import Dense,Input,Dropout
from keras.callbacks import ModelCheckpoint,TensorBoard
from keras import regularizers
# %matplotlib inline
sns.set(style='whitegrid',palette='muted',font_scale=1.5)
rcParams['figure.figsize']=10,6
RANDOM_SEED=42
LABELS=['Normal','Fraud']

# %%
#load the data
df=pd.read_csv('dataset/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Class

# %%
count_classes=pd.value_counts(df['Class'],sort=True)
count_classes.plot(kind='bar')
plt.title('Transaction class')
plt.xticks(range(2),LABELS)
plt.xlabel('class')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(df['Class'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # It can be observed that the data is highly imbalanced

# %%
frauds=df[df.Class==1]
normal=df[df.Class==0]

# %%
frauds.shape,normal.shape
# Out:
# ((492, 31), (284315, 31))

# %% [markdown]
# # Stats info of the fradualnt transaction

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# # Stats info of the non-fradualnt transaction

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# # Graphical representation

# %%
f,(ax1,ax2)=plt.subplots(2,1,sharex=True)
f.suptitle('Amount per transaction by class')
bins=50
ax1.hist(frauds.Amount,bins=bins)
ax1.set_title('Fraud')
ax2.hist(normal.Amount,bins=bins)
ax2.set_title('Normal')
plt.xlabel('Amount($)')
plt.ylabel('Number of Transaction')
plt.xlim((0,20000))
plt.yscale('log')
plt.show()

# %%
f,(ax1,ax2)=plt.subplots(2,1,sharex=True)
f.suptitle('Time of transaction Vs Amount by class')
ax1.scatter(frauds.Time,frauds.Amount)
ax1.set_title('Fraud')
ax2.scatter(normal.Time,normal.Amount)
ax2.set_title('Normal')
plt.xlabel('Time(in seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# # Preparing the data

# %%
from sklearn.preprocessing import StandardScaler
data=df.drop(['Time'],axis=1)
data['Amount']=StandardScaler().fit_transform(data['Amount'].values.reshape(-1,1))

# %%
data['Amount'][0]
# Out:
# 0.24496426337017338

# %% [markdown]
# # Split the data for training Autoencoder

# %%
xtrain,xtest=train_test_split(data,test_size=0.2,random_state=RANDOM_SEED)
xtrain=xtrain[xtrain.Class==0]
xtrain=xtrain.drop(['Class'],axis=1)
print(xtrain.shape)
print()
#print(xtrain.head(2))
# Out:
# (227451, 29)

# %%
ytest=xtest['Class']
#xtest.head()
xtest=xtest.drop(['Class'],axis=1)
xtrain=xtrain.values
xtest=xtest.values

# %%
print(xtrain.shape)
print()
print(xtest.shape)
# Out:
# (227451, 29)
#
# (56962, 29)

# %% [markdown]
# # Building Autoencoder Model

# %%
input_dim=xtrain.shape[1]
encoding_dim=14

# %%
input_layer=Input(shape=(input_dim,))
encoder=Dense(encoding_dim,activation='tanh',
 activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder=Dense(int(encoding_dim/2),activation='relu')(encoder)
decoder=Dense(int(encoding_dim/2),activation='tanh')(encoder)
decoder=Dense(input_dim,activation='relu')(decoder)
autoencoder=Model(inputs=input_layer,outputs=decoder)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 29)]              0
#
#  dense (Dense)               (None, 14)                420
#
#  dense_1 (Dense)             (None, 7)                 105
#
#  dense_2 (Dense)             (None, 7)                 56
#
#  dense_3 (Dense)             (None, 29)                232
#
# =================================================================
# Total params: 813 (3.18 KB)
# Trainable params: 813 (3.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Train the Model:

# %%
nb_epoch=30
batch_size=32
autoencoder.compile(optimizer='adam',
                     loss='mean_squared_error',
                     metrics=['accuracy'])

checkpointer=ModelCheckpoint(filepath='model_ae.h5',
                                verbose=0,
                                save_best_only=True)

tensorboard=TensorBoard(log_dir='./logs',
                        histogram_freq=0,
                        write_graph=True,
                        write_images=True)

history=autoencoder.fit(xtrain,xtrain,
                        epochs=nb_epoch,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_data=(xtest,xtest),
                        verbose=1,
                        callbacks=[checkpointer,tensorboard]).history
# Out:
# Epoch 1/30
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.8138 - accuracy: 0.5554 - val_loss: 0.7873 - val_accuracy: 0.6369
# Epoch 2/30
#   36/7108 [..............................] - ETA: 21s - loss: 0.6516 - accuracy: 0.6207
# C:\Users\2001s\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.7408 - accuracy: 0.6602 - val_loss: 0.7630 - val_accuracy: 0.6745
# Epoch 3/30
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.7256 - accuracy: 0.6846 - val_loss: 0.7557 - val_accuracy: 0.6830
# Epoch 4/30
# 7108/7108 [==============================] - 33s 5ms/step - loss: 0.7197 - accuracy: 0.6924 - val_loss: 0.7525 - val_accuracy: 0.6882
# Epoch 5/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7162 - accuracy: 0.6985 - val_loss: 0.7478 - val_accuracy: 0.7001
# Epoch 6/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7133 - accuracy: 0.7042 - val_loss: 0.7435 - val_accuracy: 0.7073
# Epoch 7/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7089 - accuracy: 0.7099 - val_loss: 0.7398 - val_accuracy: 0.7170
# Epoch 8/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7062 - accuracy: 0.7153 - val_loss: 0.7397 - val_accuracy: 0.7137
# Epoch 9/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7049 - accuracy: 0.7154 - val_loss: 0.7392 - val_accuracy: 0.7167
# Epoch 10/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7044 - accuracy: 0.7166 - val_loss: 0.7373 - val_accuracy: 0.7257
# Epoch 11/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7038 - accuracy: 0.7180 - val_loss: 0.7366 - val_accuracy: 0.7179
# Epoch 12/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7038 - accuracy: 0.7186 - val_loss: 0.7382 - val_accuracy: 0.7142
# Epoch 13/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7034 - accuracy: 0.7196 - val_loss: 0.7397 - val_accuracy: 0.7105
# Epoch 14/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7027 - accuracy: 0.7219 - val_loss: 0.7366 - val_accuracy: 0.7158
# Epoch 15/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7024 - accuracy: 0.7216 - val_loss: 0.7350 - val_accuracy: 0.7104
# Epoch 16/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7016 - accuracy: 0.7223 - val_loss: 0.7346 - val_accuracy: 0.7267
# Epoch 17/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7014 - accuracy: 0.7233 - val_loss: 0.7388 - val_accuracy: 0.7162
# Epoch 18/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7012 - accuracy: 0.7243 - val_loss: 0.7333 - val_accuracy: 0.7256
# Epoch 19/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7011 - accuracy: 0.7241 - val_loss: 0.7332 - val_accuracy: 0.7270
# Epoch 20/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7006 - accuracy: 0.7233 - val_loss: 0.7441 - val_accuracy: 0.6914
# Epoch 21/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7000 - accuracy: 0.7251 - val_loss: 0.7366 - val_accuracy: 0.7205
# Epoch 22/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7000 - accuracy: 0.7255 - val_loss: 0.7322 - val_accuracy: 0.7342
# Epoch 23/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6995 - accuracy: 0.7272 - val_loss: 0.7320 - val_accuracy: 0.7360
# Epoch 24/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6994 - accuracy: 0.7283 - val_loss: 0.7326 - val_accuracy: 0.7290
# Epoch 25/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6986 - accuracy: 0.7282 - val_loss: 0.7333 - val_accuracy: 0.7243
# Epoch 26/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6978 - accuracy: 0.7279 - val_loss: 0.7324 - val_accuracy: 0.7309
# Epoch 27/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6976 - accuracy: 0.7283 - val_loss: 0.7314 - val_accuracy: 0.7307
# Epoch 28/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6971 - accuracy: 0.7299 - val_loss: 0.7297 - val_accuracy: 0.7346
# Epoch 29/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6965 - accuracy: 0.7307 - val_loss: 0.7307 - val_accuracy: 0.7378
# Epoch 30/30
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6968 - accuracy: 0.7314 - val_loss: 0.7307 - val_accuracy: 0.7228

# %% [markdown]
# # Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model_Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train','test'],loc='upper right')

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model_Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train','test'],loc='upper right')

# %%
predictions=autoencoder.predict(xtest)
# Out:
# 1781/1781 [==============================] - 3s 2ms/step

# %%
mse=np.mean(np.power(xtest-predictions,2),axis=1)
error_df=pd.DataFrame({'Reconstruction_error':mse,'true_class':ytest})

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

threshold=2.9

ypred=[1 if e>threshold else 0 for e in error_df.Reconstruction_error.values]
conf_matrix=confusion_matrix(error_df.true_class,ypred)
sns.heatmap(conf_matrix,annot=True,xticklabels=LABELS,yticklabels=LABELS,fmt='d')
plt.title('Confusion matrix')
plt.xlabel('Predicted class')
plt.ylabel('Actual Class')
plt.show()
