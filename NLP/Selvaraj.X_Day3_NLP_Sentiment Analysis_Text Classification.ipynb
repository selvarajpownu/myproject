# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 1.Sentiment Analysis

# %%
# Sentiment Analysis using IMDb dataset
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
# Load IMDb dataset
imdb_data = pd.read_csv('NLP dataset/IMDB Dataset.csv')
imdb_data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Split data into training and testing sets
train_data, test_data, train_labels, test_labels = train_test_split(imdb_data['review'], imdb_data['sentiment'], test_size=0.2, random_state=42)

# %%
# Vectorize the text data
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(train_data)
test_vectors = vectorizer.transform(test_data)

# %%
# Train a Naive Bayes classifier
classifier = MultinomialNB()
classifier.fit(train_vectors, train_labels)
# Out:
# MultinomialNB()

# %%
# Predict sentiment on test data
predictions = classifier.predict(test_vectors)

# %%
predictions
# Out:
# array(['positive', 'positive', 'negative', ..., 'negative', 'negative',
#        'negative'], dtype='<U8')

# %%
# Evaluate accuracy
accuracy = accuracy_score(test_labels, predictions)
print(f'Sentiment Analysis Accuracy: {accuracy}')
# Out:
# Sentiment Analysis Accuracy: 0.8488

# %% [markdown]
# ### Unseen text-Prediction

# %%
# Vectorize the unseen data

unseen_data = ["I loved the movie! The plot was amazing.", 
               "The acting was terrible, and the movie was boring."]

unseen_vectors = vectorizer.transform(unseen_data)

# %%
# Predict sentiment on unseen data
predictions = classifier.predict(unseen_vectors)

# %%
# Display sentiment for each review in the unseen data
for i, review in enumerate(unseen_data):
    sentiment = 'Positive' if predictions[i] == 'positive' else 'Negative'
    print(f'Review: {review[:50]}... \nPredicted Sentiment: {sentiment}')
    print()
# Out:
# Review: I loved the movie! The plot was amazing....
# Predicted Sentiment: Positive
#
# Review: The acting was terrible, and the movie was boring....
# Predicted Sentiment: Negative

# %% [markdown]
# # 2. Text Classification

# %%
# Text Classification using 20 Newsgroups dataset
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
# Load 20 Newsgroups dataset
newsgroups_data = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# %%
# Split data into training and testing sets
train_data, test_data, train_labels, test_labels = train_test_split(newsgroups_data.data, newsgroups_data.target, test_size=0.2, random_state=42)

# %%
# Vectorize the text data
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(train_data)
test_vectors = vectorizer.transform(test_data)

# %%
# Train a Support Vector Machine (SVM) classifier
classifier = SVC()
classifier.fit(train_vectors, train_labels)
# Out:
# SVC()

# %%
# Predict categories on test data
predictions = classifier.predict(test_vectors)
predictions
# Out:
# array([ 9, 12, 14, ...,  0,  0, 12])

# %%
# Evaluate accuracy
accuracy = accuracy_score(test_labels, predictions)
print(f'Text Classification Accuracy: {accuracy}')
# Out:
# Text Classification Accuracy: 0.716710875331565

# %%
# Display predicted categories for each document
for i, document in enumerate(test_data):
    category = newsgroups_data.target_names[predictions[i]]
    print(f'Document: {document[:50]}... \nPredicted Category: {category}')
    print()
# Out:
# Document:
#
#
# 	The runner can leave his base at any time.  If...
# Predicted Category: rec.sport.baseball
#
# Document:
# Well, it's not an FTP site, but I got an 800 numb...
# Predicted Category: sci.electronics
#
# Document: Hi,
#     I was reading through "The Spaceflight Han...
# Predicted Category: sci.space
#
# Document: I was a graduate student in the early 1980s, and w...
# Predicted Category: talk.politics.misc
#
# Document: FREE-ENERGY TECHNOLOGY
#                        by R...
# Predicted Category: sci.space
#
# Document: but whoever listens to me will live in safety and ...
# Predicted Category: rec.motorcycles
#
# Document: The xgolf program was an April Fool's joke <sigh>....
# Predicted Category: sci.space
#
# Document:
# We also cannot fail to note the intense suffering...
# Predicted Category: soc.religion.christian
#
# Document: The chemicals are gone Thanks for all the response...
# Predicted Category: sci.electronics
#
# Document:
# ...
# Predicted Category: rec.autos
#
# Document:
#
# Maybe I should point out that we are not talking...
# Predicted Category: comp.graphics
#
# Document: Looking for an amateur radio operator that needs a...
# Predicted Category: misc.forsale
#
# Document:
# Oh dear, time for me to try to remember my chemis...
# Predicted Category: sci.electronics
#
# Document: Are there any TIFF to anything programs out there ...
# Predicted Category: comp.graphics
#
# Document: 'lo all,
#
#   I am writting a program that checks a ...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# Seeing as Motif has been adopted by Sun, IBM, HP...
# Predicted Category: comp.windows.x
#
# Document: Don't know who scored, but the Isles (28-7 franchi...
# Predicted Category: rec.sport.hockey
#
# Document: 1975 H-1 500
#      Brand new top end
#      Chambers
# ...
# Predicted Category: misc.forsale
#
# Document: Help, I'm bored with the current Windows backgroun...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: Two LH Research SM11-1 power supplies (SM10 series...
# Predicted Category: misc.forsale
#
# Document: I need to port several OS/2 PM applications to X (...
# Predicted Category: comp.windows.x
#
# Document:
# I heard over NPR yesterday morning that Arlan Spe...
# Predicted Category: talk.politics.guns
#
# Document: Hi Folks,
#
#    Does anyone have a copy of Playmatio...
# Predicted Category: sci.electronics
#
# Document: I wasn't sure if this was the right newsgroup to p...
# Predicted Category: soc.religion.christian
#
# Document:
# [HAMID] Anybody has any information about the num...
# Predicted Category: talk.politics.mideast
#
# Document:                                                   ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#
# This doesn't work, due to the near-field far-fie...
# Predicted Category: sci.crypt
#
# Document:
#
# Well, Michael,  I don't know if clh has left the...
# Predicted Category: soc.religion.christian
#
# Document:
# Wouldn't this require a hyper-sphere.  In 3-space...
# Predicted Category: sci.space
#
# Document:
#    Sorry, but olwm and tvtwm don't do it. They pl...
# Predicted Category: comp.windows.x
#
# Document: Can the internal hard drive of the MacPortable upg...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#     I had a kz440 and thought it was the best $10...
# Predicted Category: rec.motorcycles
#
# Document:
# If it works it's only due to the heat produced by...
# Predicted Category: comp.sys.mac.hardware
#
# Document: To all the readers of talk.politics.mideast,alt.fl...
# Predicted Category: sci.crypt
#
# Document:
# IT'S BACK!!!!!!
#
# Congratulations, you've just dis...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# Make that 20%.  Where did I see that poll recent...
# Predicted Category: alt.atheism
#
# Document:
#  I have a copy of 'The Earth-From Space' on my wa...
# Predicted Category: sci.space
#
# Document: Thanks for all the responses. I've made contact wi...
# Predicted Category: comp.graphics
#
# Document: I replied to this query via e-mail, but I think th...
# Predicted Category: alt.atheism
#
# Document:
# 	Thats pretty hard since CB900 customs weren't in...
# Predicted Category: rec.motorcycles
#
# Document:
# As long as the Yankees are in the same division t...
# Predicted Category: rec.sport.baseball
#
# Document:
# A program called Mac-ette allows you to read Mac ...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# On a related topic, I have been searching (with ...
# Predicted Category: comp.graphics
#
# Document: *****REVISED LIST**********
#
# 	I have the following...
# Predicted Category: misc.forsale
#
# Document:
# Ah, you taking everything as literal quotation.  ...
# Predicted Category: alt.atheism
#
# Document:
#
# Protestants love to play up Jerome for all he is...
# Predicted Category: soc.religion.christian
#
# Document:
# Things could be worse. A lot worse! In the mid-ei...
# Predicted Category: sci.space
#
# Document: I will instruct thee and teach thee
# 	in the way wh...
# Predicted Category: rec.motorcycles
#
# Document: Yeah, it seems toyota has always had a problem wit...
# Predicted Category: rec.autos
#
# Document: I have a problem when I'm using PostScript. When I...
# Predicted Category: comp.windows.x
#
# Document: 09 Apr 93, Susan Harwood Kaczmarczik writes to All...
# Predicted Category: soc.religion.christian
#
# Document: I have notice a lot of electronics questions by pe...
# Predicted Category: sci.electronics
#
# Document: : I was posting to Alt.locksmithing about the best...
# Predicted Category: rec.motorcycles
#
# Document: Just curious why floptical drives never seemed to ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I am having something very unusual happen.  First ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: What is Pink noise and how is it used in sound exp...
# Predicted Category: sci.electronics
#
# Document:
#
#
# Marc is not spoofing.  Try it yourself.  At lea...
# Predicted Category: sci.electronics
#
# Document: .....................................................
# Predicted Category: sci.crypt
#
# Document:
#
# Perhaps you've been under a rock since, say, the...
# Predicted Category: alt.atheism
#
# Document: Hi, I need some advice from the netland in selecti...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# It also goes like this:
#
# FED1: We need to listen ...
# Predicted Category: sci.crypt
#
# Document: Anyone catch the TV show Law & Order last night (a...
# Predicted Category: talk.politics.guns
#
# Document:
# He's been playing horrible defense. Baylor said a...
# Predicted Category: rec.sport.baseball
#
# Document: In my opinion, the limited tort option is the best...
# Predicted Category: rec.autos
#
# Document: I remember someone mention about a 150meg syquest....
# Predicted Category: sci.space
#
# Document: Does anyone know any sites/resources where I can f...
# Predicted Category: comp.windows.x
#
# Document:
# It is possible that the individual saw a true pro...
# Predicted Category: soc.religion.christian
#
# Document:
#
# I doubt if Koresh had let the BATF have a look i...
# Predicted Category: talk.politics.guns
#
# Document:
# This is not quite right.  The differential arriva...
# Predicted Category: sci.space
#
# Document: I have the following complete camera kits for sale...
# Predicted Category: misc.forsale
#
# Document: Archive-name: rec-autos/part4
#
# [this article is on...
# Predicted Category: rec.autos
#
# Document: Hi All
#
# I have a Korg DVP-1 for sale for $300.00 +...
# Predicted Category: sci.electronics
#
# Document: Up until last week, I have been running POVray v1....
# Predicted Category: comp.graphics
#
# Document:
# : Does anyone know about these studies? Or have e...
# Predicted Category: sci.med
#
# Document: Selling -
#
#           Arnet Multiport card. Four se...
# Predicted Category: misc.forsale
#
# Document: I was in the great storm.....my Mazda MPV was dama...
# Predicted Category: rec.autos
#
# Document:
#
#
#
#
# Well, regardless of what policy liabilities a...
# Predicted Category: sci.crypt
#
# Document: Please reply to the seller below.
#
# For Sale:
#
# Exab...
# Predicted Category: misc.forsale
#
# Document:
#
# No, this is not true. the CNN pictures show two ...
# Predicted Category: sci.electronics
#
# Document: I am DESPERATELY trying to find a PC based e-mail ...
# Predicted Category: comp.windows.x
#
# Document: ...
# Predicted Category: rec.autos
#
# Document: Arthur Melnick posts an interesting first-hand mes...
# Predicted Category: alt.atheism
#
# Document: Help!
#
# I'm trying to run dxterm's (DECs' xterm) on...
# Predicted Category: comp.windows.x
#
# Document: Having been gone for 10 days, I'm way behind on my...
# Predicted Category: sci.med
#
# Document: Archive-name: graphics/resources-list/part1
# Last-m...
# Predicted Category: comp.graphics
#
# Document:
#
#
# I'll have to disagree with you on this one. I t...
# Predicted Category: rec.sport.hockey
#
# Document: :
# : > Surely you are not equating David Koresh wi...
# Predicted Category: talk.religion.misc
#
# Document:
#
# Krillean photography involves taking pictures of...
# Predicted Category: sci.med
#
# Document: FOR SALE:
#
# Trident 1 Meg Video Card
#
# Up to 1024x76...
# Predicted Category: misc.forsale
#
# Document:
#
# At the cost of repudiating the FAQ, I think too ...
# Predicted Category: alt.atheism
#
# Document: Having read the various "Clipper" announcements on...
# Predicted Category: sci.crypt
#
# Document: Excerpts from netnews.talk.politics.guns: 18-Apr-9...
# Predicted Category: talk.politics.guns
#
# Document: My wife has requested that I poll the Sages of Use...
# Predicted Category: sci.med
#
# Document: Hello,
#
# in the EDN magazine I found a note about t...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#   There's documentation on how to use the shared ...
# Predicted Category: comp.windows.x
#
# Document: One way ticket (return leg of roundtrip ticket) fo...
# Predicted Category: misc.forsale
#
# Document:
#
#
# How about some numbers here? Some kind of bench...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Seagate 1.2GB SCSI hard Drive
# Brand NEW with full ...
# Predicted Category: misc.forsale
#
# Document: ...
# Predicted Category: rec.autos
#
# Document: i saw this posted and it brings an interesting eve...
# Predicted Category: soc.religion.christian
#
# Document:
#    _The_ problem with Oort cloud sources is that ...
# Predicted Category: sci.space
#
# Document: Does anyone know of any type of acceleration senso...
# Predicted Category: sci.electronics
#
# Document: Hmm.  $1 billion, lesse... I can probably launch 1...
# Predicted Category: sci.space
#
# Document: I can't find CTDS (Connect The Dots Smoother) in F...
# Predicted Category: comp.graphics
#
# Document: Ok people, I really need to sell this sampler to p...
# Predicted Category: misc.forsale
#
# Document:
#
# Local LA stores have already reduced prices by $...
# Predicted Category: comp.sys.mac.hardware
#
# Document: To all the Braves doubters:
#
# Don't worry.  The bat...
# Predicted Category: rec.sport.baseball
#
# Document:
# You could do what I do: never go near the stuff! ...
# Predicted Category: rec.motorcycles
#
# Document:
#
# No.  The simple $25 style IDE controller does no...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I wonder if anyone can tell me whether or not I ca...
# Predicted Category: comp.windows.x
#
# Document:
#
# Well, it did not take long to see how consequent...
# Predicted Category: talk.politics.mideast
#
# Document: I would like to know if a Performa Plus monitor is...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
#
#
#
#
#
# Again, I do not speak for Peter Tattam, but...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# I...
# Predicted Category: rec.autos
#
# Document: ...
# Predicted Category: rec.autos
#
# Document:
# "Society" is impossible without some shared set o...
# Predicted Category: alt.atheism
#
# Document:
# Why don't you tell us, Tony?  I'm sure what you T...
# Predicted Category: alt.atheism
#
# Document:
#
# With regards to what you wrote, how does one "a...
# Predicted Category: sci.electronics
#
# Document:
#
# I use the Diamond SpeedStar 24X in 1024X768X256 ...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# This is one of those "yes, but" things. It's true...
# Predicted Category: alt.atheism
#
# Document: This is a test. Thanks.
# ...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# You forgot the smiley-face.
#
# I can't believe this...
# Predicted Category: rec.motorcycles
#
# Document:
# How does that saying go: Those who say it can't b...
# Predicted Category: alt.atheism
#
# Document:
#
# Here is the short answer: because only
# certain m...
# Predicted Category: soc.religion.christian
#
# Document: ...
# Predicted Category: rec.autos
#
# Document:
# ...
# Predicted Category: rec.autos
#
# Document:
# 	I like it.  PGP would be useful, I guess.  Altho...
# Predicted Category: sci.crypt
#
# Document: On an ISO/ANSI-standard 5.25" magneto-optical disc...
# Predicted Category: misc.forsale
#
# Document: 93!04.16 e.v.  After the Glorious Eve of Taxation
# ...
# Predicted Category: soc.religion.christian
#
# Document:
# Two shots at it: (1) Check the tires again - if y...
# Predicted Category: rec.motorcycles
#
# Document:
# Well, that post was not that accurate.  People wi...
# Predicted Category: sci.med
#
# Document:
# [...]
#
# Wait a minute, Doug.  I know you are bette...
# Predicted Category: talk.politics.mideast
#
# Document: With the popularity of minivans, the market room f...
# Predicted Category: rec.autos
#
# Document:
#
# I sure hope so. Because, the unspeakable crimes ...
# Predicted Category: talk.politics.mideast
#
# Document:
# 	Down to 170-some odd lines.  We must be making p...
# Predicted Category: talk.politics.guns
#
# Document: : In article <11838@vice.ICO.TEK.COM>, bobbe@vice....
# Predicted Category: alt.atheism
#
# Document:
# I'm not sure it is a major limiting move... in th...
# Predicted Category: sci.crypt
#
# Document:
#
# I believe that CPR is himself such a "house Jew"...
# Predicted Category: talk.politics.mideast
#
# Document: Hello Neo-Geo owners (and non-owners who couldn't ...
# Predicted Category: rec.sport.baseball
#
# Document:
# LIST OF KILLINGS IN THE NAME OF RELIGION
# 1. Iran...
# Predicted Category: rec.sport.baseball
#
# Document:
#
#
#
#
# We have no way of knowing because we cannot s...
# Predicted Category: rec.sport.baseball
#
# Document:
# Any lunar satellite needs fuel to do regular orbi...
# Predicted Category: sci.space
#
# Document:
#
#  Opps!  typed in the phone numbers wrong.  Here ...
# Predicted Category: sci.electronics
#
# Document: I'm looking for some specs for a Toshiba TA6267-BP...
# Predicted Category: sci.electronics
#
# Document: Dbase IV, ver 1.5, 3.5 disks.  Manuals still shrin...
# Predicted Category: misc.forsale
#
# Document:     Just observed at the National Model United Nat...
# Predicted Category: rec.motorcycles
#
# Document:
# -> I saw an interesting product in NY Auto Show, ...
# Predicted Category: rec.autos
#
# Document:
#
# Oops! Quite right. I got so busy that I saved Fr...
# Predicted Category: alt.atheism
#
# Document:
# I think the original poster meant opening the mou...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# Try Parts Express in Dayton, Ohio also.  They hav...
# Predicted Category: sci.electronics
#
# Document:
# My very favorite ad for such a device is on the b...
# Predicted Category: sci.electronics
#
# Document:
#
# export.lcs.mit.edu:/contrib/R5.SunOS5.patch.tar....
# Predicted Category: comp.windows.x
#
# Document:
#
# I've had, and still have a few aluminum sticks. ...
# Predicted Category: rec.motorcycles
#
# Document: Two years old Crate Guitar Amplifier model G80XL. ...
# Predicted Category: misc.forsale
#
# Document: Hello,
#
#    Let me introduce a problem:
#
#    When I...
# Predicted Category: sci.electronics
#
# Document:
#
#  | You certainly do not see OTC preparations adv...
# Predicted Category: sci.med
#
# Document:
# Hmmm... Interesting. What do you mean by WALKING ...
# Predicted Category: rec.motorcycles
#
# Document: One of those "morning, just getting the coffee in ...
# Predicted Category: rec.motorcycles
#
# Document: ...
# Predicted Category: rec.autos
#
# Document:
# You've overlooked a fundamental Truth:
#
# 	both hea...
# Predicted Category: sci.crypt
#
# Document: The only ether I see here is the stuff you must
# ha...
# Predicted Category: sci.space
#
# Document: In Texas (Well, Corpus Christi anyway) if you pick...
# Predicted Category: sci.electronics
#
# Document: Subject says it all :)
#
# I'm looking for the jumper...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# [...stuff deleted...]
#
# Andy-- I think we do agree...
# Predicted Category: alt.atheism
#
# Document:
#    You might try the rec.models.rockets newsgroup...
# Predicted Category: sci.space
#
# Document:
#
# Actually, both numbers are correct.  The differe...
# Predicted Category: sci.space
#
# Document: Hi Damon,  No matter what system or explanation of...
# Predicted Category: alt.atheism
#
# Document: First of all, thanks to those of you who responded...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: Rich Thompson posts some blather about the Liberta...
# Predicted Category: rec.sport.baseball
#
# Document:
#
#
#  Well, if you put things into historical perspe...
# Predicted Category: talk.politics.mideast
#
# Document: I recently installed dos 5.0 on a few machines, an...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: Gentlefolk,
#
#         It seems to me that the "Step...
# Predicted Category: sci.crypt
#
# Document:
#
# so when is PRODIGY going to open the doors for i...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# ]The "corrupted over and over" theory is pretty ...
# Predicted Category: soc.religion.christian
#
# Document: xIf you put a locking lugnut on your tires, do you...
# Predicted Category: rec.autos
#
# Document: Followup-To:kedz@wpi.wpi.edu
# Distribution: ne
# Org...
# Predicted Category: rec.motorcycles
#
# Document: If you haven't heard yet, US Senator Patty Murrey,...
# Predicted Category: talk.politics.guns
#
# Document: t
#
#
# The original poster never said they were afrai...
# Predicted Category: talk.politics.misc
#
# Document: **************************************************...
# Predicted Category: comp.graphics
#
# Document:
#
#
#
#          The BATF warrant was unsealed yesterd...
# Predicted Category: talk.politics.guns
#
# Document:
# [horror story about FBI ruining a guy's life for ...
# Predicted Category: alt.atheism
#
# Document: Here's a question that may be simple enough to ans...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Hello src readers,
#
# Again the misconception that C...
# Predicted Category: soc.religion.christian
#
# Document:
# (Deletion)
#
# Read a history book, Fred. And tell...
# Predicted Category: alt.atheism
#
# Document: #
# #
# # Is there an Xt call to give me my applicat...
# Predicted Category: comp.windows.x
#
# Document:
# Just thought I would mention that Sony no longer ...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# How is a scriptural Levitical priesthood resumed...
# Predicted Category: talk.politics.mideast
#
# Document: Frank, I got your mailing on early historical refe...
# Predicted Category: misc.forsale
#
# Document:
#
#
# We're having to associate with you against our ...
# Predicted Category: talk.politics.misc
#
# Document: I booked a hotel (Red Roof Inn) last week in Cinci...
# Predicted Category: sci.electronics
#
# Document: There is a guy in NASA Johnson Space Center  that ...
# Predicted Category: sci.space
#
# Document:
#
#
#
# Whoa.  What you are effectively doing is imply...
# Predicted Category: rec.sport.hockey
#
# Document:
# There is no law prohibiting having biological wea...
# Predicted Category: talk.politics.guns
#
# Document: Hello again,
#
# About a week and one-half ago I post...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# Uh, why do they have to ask a state commision? U...
# Predicted Category: sci.space
#
# Document: Buffalo fans:
#
# Some people in the discussion group...
# Predicted Category: rec.sport.hockey
#
# Document:
# In the same way in which antisemite means anti-Je...
# Predicted Category: talk.politics.mideast
#
# Document:
#
# 	Huh?  Mohamed Salimeh was perhaps a Korean?  Ho...
# Predicted Category: talk.politics.mideast
#
# Document: On one of the morning shows (I think is was the To...
# Predicted Category: talk.religion.misc
#
# Document: Here is a press release from the American Federati...
# Predicted Category: talk.politics.misc
#
# Document: The subject line says it all really, I'm looking f...
# Predicted Category: comp.graphics
#
# Document: Here is how I modified my Quadra 700 for higher sp...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Replying to A.J. Teel:
#
# 	Well, the two nifty lette...
# Predicted Category: talk.politics.misc
#
# Document:
# As a general rule, no relay will cleanly switch a...
# Predicted Category: sci.electronics
#
# Document: [bits deleted]
#
#
# I'd be fascinated to see such evi...
# Predicted Category: sci.med
#
# Document: Xircom Pocket Ethernet Adapter
# Connects any PC wit...
# Predicted Category: misc.forsale
#
# Document: Can someone please remind me who said a well known...
# Predicted Category: sci.space
#
# Document: 	So, if the Braves run production falls to 1 per g...
# Predicted Category: rec.sport.baseball
#
# Document:
# When they explode 'em, all the screws fly away....
# Predicted Category: rec.motorcycles
#
# Document:
#
#
# Look up the facts first, post second.  Bernadot...
# Predicted Category: talk.politics.mideast
#
# Document:
# 	These drivers (updated) are available directly f...
# Predicted Category: rec.motorcycles
#
# Document:
# But what about second sources for pin-compatible ...
# Predicted Category: sci.crypt
#
# Document:
# I get regular questions about gamma correction si...
# Predicted Category: comp.graphics
#
# Document: (Detroit, April 19)
#
# In a development that shocked...
# Predicted Category: rec.sport.hockey
#
# Document: Please help if you can with the following strange ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I am working on an X-Window based application that...
# Predicted Category: comp.windows.x
#
# Document: Yamanari,
#
# ---Hey isn't it funny how betas have bu...
# Predicted Category: rec.motorcycles
#
# Document:
# It is also interesting to note that Powell (and m...
# Predicted Category: talk.politics.misc
#
# Document: It is usually possible to reach people at IKI (Ins...
# Predicted Category: sci.space
#
# Document:
#
#
#
#
# I don't sign any blank checks.
#
# When Doug Fox...
# Predicted Category: talk.politics.guns
#
# Document: Hi,
#
# I'm working on a project that involves storin...
# Predicted Category: comp.graphics
#
# Document:
# How about letting in the press?
#
# How about lettin...
# Predicted Category: talk.politics.guns
#
# Document: Would someone please send me James Oberg's email a...
# Predicted Category: rec.sport.baseball
#
# Document:
#
# NOOOOOOOOOOOOOOOOO!  Who's the mindscheme(?) beh...
# Predicted Category: rec.sport.baseball
#
# Document:
# wondering
#                                        ...
# Predicted Category: rec.sport.baseball
#
# Document:
# ...
# Predicted Category: rec.autos
#
# Document:
#
#
# The existence of the weapon in and of itself (a...
# Predicted Category: talk.politics.guns
#
# Document: I love the FAQ.
#
# The comment about contact ...
# Predicted Category: sci.med
#
# Document: What would be a good platform for some fairly basi...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# 	Have the feds shut down the people making Sound ...
# Predicted Category: sci.crypt
#
# Document: I recently backed out of purchasing an almost-unus...
# Predicted Category: sci.electronics
#
# Document: A friend of mine has been diagnosed with Psoriatic...
# Predicted Category: sci.med
#
# Document: Suppose the Soviets had managed to get their moon ...
# Predicted Category: sci.space
#
# Document:
#
# I won't even recommend books from my congregatio...
# Predicted Category: soc.religion.christian
#
# Document:
#
# There is a great book out called "They Also Serv...
# Predicted Category: rec.sport.baseball
#
# Document:
#
# Again, you missed Jesus's point.  If you read th...
# Predicted Category: soc.religion.christian
#
# Document:
#
# 	When I might possibly be on the receiving end o...
# Predicted Category: soc.religion.christian
#
# Document:
#
#
#
# Is it appropriate for the Lord not to reveal c...
# Predicted Category: soc.religion.christian
#
# Document:
# It also gave me lots of problems with joint and m...
# Predicted Category: sci.med
#
# Document: In <1993Apr21.211038.12363@newshub.ists.ca> dchhab...
# Predicted Category: rec.motorcycles
#
# Document: I look at zApp and really liked it. However, I thi...
# Predicted Category: comp.graphics
#
# Document:
#  ]In article <C4vr7z.EB0@usenet.ucs.indiana.edu>,...
# Predicted Category: comp.sys.mac.hardware
#
# Document: [ Lots of stuff deleted because I felt like it ]
#
# ...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: The subject line says it all. I'm working on a pro...
# Predicted Category: rec.autos
#
# Document: [..stuff deleted]
# Oh, but can Big Brother afford s...
# Predicted Category: sci.crypt
#
# Document: I would like to find a Windows 3.x driver for a vi...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: In a Philadelphia Inquirer a few days ago, it was ...
# Predicted Category: rec.sport.baseball
#
# Document:
#
# You are quite correct in your understanding.  Th...
# Predicted Category: sci.electronics
#
# Document:
#
#
#
#
# Didn't one of the early jet fighters have the...
# Predicted Category: sci.space
#
# Document:
#
# How many NuBus slots do you have?
#
# Applied Engin...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# Well, I also have an LC III.  Popping the top rev...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# Seeing as how people are willing to quote the FB...
# Predicted Category: talk.politics.guns
#
# Document: The complete set of the adventures of Buck Rogers ...
# Predicted Category: misc.forsale
#
# Document: Hi all,
#  I've been following this thread about jac...
# Predicted Category: sci.electronics
#
# Document: Only as far as it affects the crime rate.
#
# Did the...
# Predicted Category: talk.politics.guns
#
# Document: Ok, here goes.  Yes folks, I realize I have stuck ...
# Predicted Category: talk.politics.guns
#
# Document:
# : >True, man did not invent the need for food, sh...
# Predicted Category: talk.politics.misc
#
# Document: begin 644 outOfControl.gif
# M1TE&.#=AN@*6`?```````/...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# Yes.  But this is *irrelevant*.  You're talking a...
# Predicted Category: rec.sport.baseball
#
# Document: Spike is owned by both Tom and I.  We went 1/2's o...
# Predicted Category: rec.motorcycles
#
# Document:
# To paraphrase, I may not agree with what you're e...
# Predicted Category: rec.motorcycles
#
# Document: There is a new DoD listing. To get a copy use one ...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# Please, PAY ATTENTION.
# I, and others, were referr...
# Predicted Category: talk.politics.guns
#
# Document: Here is a way to get the commericial companies int...
# Predicted Category: sci.space
#
# Document:
#
#
# If true, and if gays were the same as straights...
# Predicted Category: comp.graphics
#
# Document:
#
# So how much would it cost as a private venture, ...
# Predicted Category: sci.space
#
# Document:
# Maybe he will. Maybe he is working for the secret...
# Predicted Category: talk.politics.mideast
#
# Document: libXaw3d, the 3D Athena widget set will greatly im...
# Predicted Category: comp.windows.x
#
# Document:
# I would change one of the many parts that define ...
# Predicted Category: alt.atheism
#
# Document: My original post:
#
# Aha, I think I found the proble...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# It isn't that rare, actually.  Many cases that ar...
# Predicted Category: sci.med
#
# Document:
# But in this case I said I hoped that BCCI was *no...
# Predicted Category: alt.atheism
#
# Document:
# 	"And in that day you will ask Me no question.  T...
# Predicted Category: soc.religion.christian
#
# Document:
# Well, actually, the Davidians (Koreshians?) start...
# Predicted Category: talk.politics.guns
#
# Document: I have an addition to the FAQ regarding "why are t...
# Predicted Category: alt.atheism
#
# Document: I'm looking for a better method to back up files. ...
# Predicted Category: comp.graphics
#
# Document:
# You might visit some congregations of Christians,...
# Predicted Category: soc.religion.christian
#
# Document: STK1203@VAX003.STOCKTON.EDU Pontificated:
#
# One of...
# Predicted Category: sci.space
#
# Document:
# how so? i think you're making assumptions here th...
# Predicted Category: talk.politics.guns
#
# Document:
# I hope I didn't award custody, Rich.  I purposely...
# Predicted Category: soc.religion.christian
#
# Document: : Does anyone know what is available in terms of a...
# Predicted Category: comp.windows.x
#
# Document:
# I was replying to a person who attempted to justi...
# Predicted Category: alt.atheism
#
# Document:
#
# The peaceful attempt to serve the warrant was me...
# Predicted Category: talk.politics.guns
#
# Document: Actually not Jim.  I just said that everyone else ...
# Predicted Category: alt.atheism
#
# Document: Any one with experience in having a centreforce cl...
# Predicted Category: rec.autos
#
# Document: consistently
#
#
# ...
# Predicted Category: rec.motorcycles
#
# Document: A new alternative to Scouting for those "unaccepta...
# Predicted Category: talk.politics.misc
#
# Document: ...
# Predicted Category: rec.autos
#
# Document:
# Well, yes and no.  The _image_ can't be on the sc...
# Predicted Category: comp.graphics
#
# Document: I have a Paradise SVGA with 1Mb, the 90c030 chip (...
# Predicted Category: comp.graphics
#
# Document:
# Sorry folks, I should have done this, and meant t...
# Predicted Category: sci.space
#
# Document:
#
#
# 			  ^^^^^^^^^
#
# huh? it might be interesting. h...
# Predicted Category: rec.motorcycles
#
# Document:
# I attribute my success to several factors:
#
# Very ...
# Predicted Category: sci.med
#
# Document:
#
#
#
# Hmm, it seems the Little Leaguers didn't do to...
# Predicted Category: rec.motorcycles
#
# Document:
# I see that I misphrased my question.  I should ha...
# Predicted Category: talk.politics.guns
#
# Document: When is Apple supposed to start bundlign the new e...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Hello there!
#
# A week ago a guy asked what a .SCO f...
# Predicted Category: comp.graphics
#
# Document: [stuff deleted about Microsoft]
# You must of read t...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: [...]
# [...]
#
#
# Oh, lord.  This is where I came in.
# ...
# Predicted Category: rec.motorcycles
#
# Document:
# 	.
# 	.
# 	.
#
# Why do you assume that Jesus's plea to ...
# Predicted Category: soc.religion.christian
#
# Document: From article <1993Apr22.165659.8890@desire.wright....
# Predicted Category: comp.sys.mac.hardware
#
# Document: For sale :
#
#
#
#
# 	Bose A5 subwoofer 1 month old
#
# 	2 ...
# Predicted Category: misc.forsale
#
# Document:
#
# According to MacWeek of 2-22-93:
#
# The Cyclone wi...
# Predicted Category: comp.sys.mac.hardware
#
# Document: You can get a NEW newer model for a cheaper price ...
# Predicted Category: misc.forsale
#
# Document: Cool off!  These people have as much right to be h...
# Predicted Category: talk.politics.misc
#
# Document:
#
#
#
# Here's a rough sketch of how the system works....
# Predicted Category: sci.electronics
#
# Document: hi,
#
# try DontZap in /usr/lib/X11/Xconfig
#
# cu
# 	styx...
# Predicted Category: comp.windows.x
#
# Document:
#
#        This seems a strange argument to make con...
# Predicted Category: talk.politics.guns
#
# Document: What files do I need to download for GhostScript 2...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# Any suggestions as to what a better solution migh...
# Predicted Category: talk.politics.misc
#
# Document: Hi.  One of my coworkers is having a very odd prob...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# I quote from the journal, "30 Days In the Church...
# Predicted Category: soc.religion.christian
#
# Document:
# While I didn't try the expansion personally, I kn...
# Predicted Category: rec.motorcycles
#
# Document:
# For starters, they could have gone on waiting and...
# Predicted Category: talk.politics.guns
#
# Document: Hello,
#
# Has anyone used the Requirements Analsys m...
# Predicted Category: comp.graphics
#
# Document: Does anybody know of any information regarding the...
# Predicted Category: sci.med
#
# Document:
#
# 	Wrong.  Zionism *acknowledges* the fact that an...
# Predicted Category: talk.politics.mideast
#
# Document: I'd like to install an Apple (Quantum) 40 MB hard ...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Friend's unpleasant experience uring CT scan delet...
# Predicted Category: sci.med
#
# Document:
# (Deletion)
#
# It has. There is a guy running arou...
# Predicted Category: alt.atheism
#
# Document:
#
# Is that how the mind of a compulsive liar works?...
# Predicted Category: talk.politics.mideast
#
# Document:
# Gee, I remember the old 8" FLOPPY disks we used o...
# Predicted Category: sci.electronics
#
# Document: Mysstem crashes aftwer sleepp.  I use 1.0.1 enable...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#      There is no such thing as "completely secure...
# Predicted Category: sci.space
#
# Document:
#
# What about black hispanics?
#
# 			    ^^^^^^^^^^^^...
# Predicted Category: rec.motorcycles
#
# Document: hartzman@kilroy.Jpl.Nasa.Gov (Les Hartzman) writes...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# Oh, really. When?
#
#
# The '93 Mustang Cobra can. Ch...
# Predicted Category: rec.autos
#
# Document:
# Any prize like this is going to need to be worded...
# Predicted Category: sci.space
#
# Document: ...
# Predicted Category: rec.autos
#
# Document: My schedule is flexible so any games are candidate...
# Predicted Category: rec.sport.baseball
#
# Document:
# Place your hands flat on a table, and arrange the...
# Predicted Category: rec.motorcycles
#
# Document:
# Not enough magtape.
#
# Seriously, do you have any i...
# Predicted Category: rec.autos
#
# Document: <KIME.93Apr20133127@mongoose.torolab.ibm.com> <mjo...
# Predicted Category: rec.sport.baseball
#
# Document:
# I just called them and they said the order went o...
# Predicted Category: rec.motorcycles
#
# Document: I have had a Gateway Telepath modem for about a mo...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: Hi! I recently got hold of an old/obsolete PC. Fir...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: Why don't you look again at Motor Trend's, slalom ...
# Predicted Category: rec.autos
#
# Document: I've got the official word on the LaserWriter Pro ...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Sorry,  forgot to add its a Jap.  import
# Andy
# ...
# Predicted Category: sci.space
#
# Document:
#
# Officially, no. From experience (yours now inclu...
# Predicted Category: comp.sys.mac.hardware
#
# Document: 10).
#
#   A 256K DRAM chip is a 256 kilobit chip wh...
# Predicted Category: comp.sys.mac.hardware
#
# Document:  I know this is a little weird, but I know that Wo...
# Predicted Category: sci.med
#
# Document:
# The DeLorean had the yucky PRV V6 engine. A joint...
# Predicted Category: rec.autos
#
# Document:
#
#
#
# They police did not beat King when he was on t...
# Predicted Category: rec.sport.hockey
#
# Document: } >} [Stuff about upated inning scores deleted.]
# }...
# Predicted Category: rec.sport.baseball
#
# Document: I use the new keyboard with a IIfx, and I like it....
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# I don't understand the assumption that because s...
# Predicted Category: sci.med
#
# Document: I've done a bit of looking, and havn't been able t...
# Predicted Category: comp.graphics
#
# Document: Anybody seen mouse cursor distortion running the D...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: Archive-name: graphics/resources-list/part3
# Last-m...
# Predicted Category: comp.graphics
#
# Document:
# This sounds to me like a sort of generic modalism...
# Predicted Category: soc.religion.christian
#
# Document:
# :    The upgrade to a Nanao 550i is now $765.
# :  ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# Hmmmmn...don't you ride with your sweetheart?
#
# -...
# Predicted Category: rec.motorcycles
#
# Document: I just got a copy of Tobias' Managing Your Money v...
# Predicted Category: sci.electronics
#
# Document: ------------- cut here -----------------
#
#        ...
# Predicted Category: sci.med
#
# Document:
# I bought a Bernoulli 90pro drive last year after ...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# There is a number you can call which will return ...
# Predicted Category: sci.electronics
#
# Document: Sorry Charlie...
#
# I have a dozen, VERY blue LED's ...
# Predicted Category: sci.electronics
#
# Document: Hi there,
#
#     I plan on upgrading my monitor and ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: 930425
#
#
# Rome was under attack by barbarians, the...
# Predicted Category: talk.religion.misc
#
# Document:
#
# sorta.
#
#
# '88 Honda Hawk
#
# YMMV....
# Predicted Category: rec.motorcycles
#
# Document:
# Please define the words "shatim" and "fasad" befo...
# Predicted Category: comp.windows.x
#
# Document: The Duo's can drive Apple's 16" monitor at 832x624...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# I wholeheartedly agree.  Knowing that WE have let...
# Predicted Category: talk.politics.misc
#
# Document:
# I think the next time I post something like this,...
# Predicted Category: sci.space
#
# Document:
# 	Viola has only played in the NL with the Mets --...
# Predicted Category: rec.sport.baseball
#
# Document:
# [a lot of stuff deleted -- i'm focusing on just o...
# Predicted Category: alt.atheism
#
# Document:
#
# I believe that this is not quite correct. My und...
# Predicted Category: soc.religion.christian
#
# Document: I don't think speed has been determined, since it ...
# Predicted Category: sci.electronics
#
# Document: What is the status of cruptology for private citiz...
# Predicted Category: sci.crypt
#
# Document:
#
# I had this problem when I first loaded windows. ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#
# There was an article in USA today a few months a...
# Predicted Category: soc.religion.christian
#
# Document: Is there a way to connect a PowerBook 145, Mac IIs...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# But they also might have run out of fire-wood (ma...
# Predicted Category: talk.politics.guns
#
# Document: I need a graphics display program that can take as...
# Predicted Category: comp.graphics
#
# Document:
#  >
#  > Regarding the horror stories about DOS6/DO...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# Gee, then I guess the extra horn that's mounted i...
# Predicted Category: rec.autos
#
# Document: Does anybody know if there is a mailing list or ne...
# Predicted Category: sci.electronics
#
# Document:
#
# Now *this* is a legitimate point.  Baseball is e...
# Predicted Category: rec.sport.baseball
#
# Document:
# I used to think this way, and not just about X. F...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# For the first Move incident (no bomb, several mem...
# Predicted Category: talk.politics.guns
#
# Document: Ok, this might seem a bit odd.
# How do check the st...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#
# Because most of the children were with their par...
# Predicted Category: talk.politics.misc
#
# Document: [insert deletion of Paul's and Aaron's discourse o...
# Predicted Category: soc.religion.christian
#
# Document: :
# : I believe this raid was ill planned because t...
# Predicted Category: talk.politics.guns
#
# Document: Does anyone know of a program or utility that will...
# Predicted Category: comp.sys.mac.hardware
#
# Document: From: thwang@mentor.cc.purdue.edu (Tommy Hwang)
# Su...
# Predicted Category: rec.autos
#
# Document: : >I want to upgrade my system and was thinking of...
# Predicted Category: sci.electronics
#
# Document: Thanks to all those people who recommended Workspa...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: fans into the game but surely they would rather se...
# Predicted Category: rec.sport.hockey
#
# Document: We are doing a research about a passive dynamic vi...
# Predicted Category: comp.graphics
#
# Document: I am trying to get my system to work with a Tandbe...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I'm told that I can replace the colorful windows l...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: Does anybody out there have one of those food dehy...
# Predicted Category: sci.electronics
#
# Document:
# 	If the Leaf's play like they did in game one the...
# Predicted Category: rec.sport.hockey
#
# Document: I am making a search for a CAD program that does a...
# Predicted Category: comp.graphics
#
# Document: :    Where can I get xman source?  I would like to...
# Predicted Category: comp.windows.x
#
# Document: I'm going to be purchasing one of these soom for m...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#
# Let us not forget about the genocide of the Azer...
# Predicted Category: talk.politics.mideast
#
# Document:
#   No, that's praying on the young.  Preying on ...
# Predicted Category: alt.atheism
#
# Document:
#     The immunization program is just a "useful fi...
# Predicted Category: talk.politics.misc
#
# Document: 	Lots of house fires give off black sooty smoke.  ...
# Predicted Category: talk.politics.guns
#
# Document:
#
# 	"So after 1000 years of sightseeing and roaming...
# Predicted Category: talk.politics.mideast
#
# Document: critus
#
#
#
#
#
# ...
# Predicted Category: rec.autos
#
# Document: : Are the Serbs doing the work of God?  Hmm...
#
# : ...
# Predicted Category: soc.religion.christian
#
# Document:    Once it hits land you can record it if you have...
# Predicted Category: sci.crypt
#
# Document:
# I would recommend "Essential Truthes of the Chris...
# Predicted Category: soc.religion.christian
#
# Document:
# Here in switzerland, the situation is exactly the...
# Predicted Category: sci.electronics
#
# Document: # ## Absolutely nothing, seeing as there is no tab...
# Predicted Category: talk.politics.misc
#
# Document: In <1993Apr21.175443.5338@dct.ac.uk> mcsdc1jpb@dct...
# Predicted Category: talk.politics.guns
#
# Document: I just wanted to know:...
# Predicted Category: misc.forsale
#
# Document:
# Yes, I do.  A couple of years ago, I did a compar...
# Predicted Category: comp.graphics
#
# Document:    Would you like fries with that, sir?
# ...
# Predicted Category: rec.motorcycles
#
# Document: My wife had hives during the first two months
# of h...
# Predicted Category: sci.med
#
# Document:
#
# Wow, this is news to me---it started in Tarsus...
# Predicted Category: sci.space
#
# Document: : The median of a distribution is that variate-val...
# Predicted Category: talk.politics.misc
#
# Document: [..]
#
# Possibly the parallel just stems from your t...
# Predicted Category: alt.atheism
#
# Document: Where can I find it ?...
# Predicted Category: comp.windows.x
#
# Document: Source: "Adventures in the Near East" by A. Rawlin...
# Predicted Category: talk.politics.mideast
#
# Document:
# Perhaps it's time to start rec.sport.baseball.gra...
# Predicted Category: rec.sport.baseball
#
# Document:   >>
#   >>    Environment:
#   >>       mach/arch : ...
# Predicted Category: comp.windows.x
#
# Document:
# Jeff Fenholt claims to have once been a roadie fo...
# Predicted Category: soc.religion.christian
#
# Document: The trackbal on my PB140 no longer moves in the ho...
# Predicted Category: comp.sys.mac.hardware
#
# Document: long
#
# The NRA is successful because (among a numbe...
# Predicted Category: sci.crypt
#
# Document:
# Are you for real?
#
# People dumb enough to give the...
# Predicted Category: rec.sport.baseball
#
# Document:
#  Rabin is the PM. Did he ever indicate such a wis...
# Predicted Category: rec.sport.baseball
#
# Document:
#
#
#
#
# Roger, you should check your facts before pos...
# Predicted Category: rec.sport.hockey
#
# Document:
# That's funny, I thought you were making a stateme...
# Predicted Category: talk.politics.misc
#
# Document:
# I believe it is illegal to send any cryptographic...
# Predicted Category: sci.crypt
#
# Document: This is being posted as a general outline for your...
# Predicted Category: soc.religion.christian
#
# Document: ...
#
# 	Nearly all of them.  Witness LA>  Firemen ar...
# Predicted Category: talk.politics.guns
#
# Document: Hi, I'm new to this group so please bear with me!
# ...
# Predicted Category: comp.windows.x
#
# Document: Doug Holland claims Tom Clancy has provided the re...
# Predicted Category: rec.sport.baseball
#
# Document:
# First off, with all these huge software packages ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# I think what Bob is describing here is a game whi...
# Predicted Category: rec.sport.baseball
#
# Document: a global key G, plus one key U_C for each chip C. ...
# Predicted Category: sci.crypt
#
# Document: Hi, all hardware netters,
#
#   I've seen recently on...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: In the EC, the Corrado VR6 is rated as 'best handl...
# Predicted Category: rec.autos
#
# Document: I am beginning an e-mail discussion group about ce...
# Predicted Category: soc.religion.christian
#
# Document:
#
# They sure make it sound like that.
#
#
# Even a simp...
# Predicted Category: talk.politics.guns
#
# Document: Cyrix have released a 386 pin-conpatible 486 clone...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
#
# Make that ten, not eight. The Mets and Astros jo...
# Predicted Category: rec.sport.baseball
#
# Document:
#
# ra>   Robert, you keep making references to "ort...
# Predicted Category: soc.religion.christian
#
# Document: The following are available for $7.00 each (includ...
# Predicted Category: misc.forsale
#
# Document: I just wanted to let everyone know that I have los...
# Predicted Category: rec.sport.baseball
#
# Document: I need to make a power supply that can take input ...
# Predicted Category: sci.electronics
#
# Document: 1993 World Championships in Germany:
#  ============...
# Predicted Category: rec.sport.hockey
#
# Document: I have uploaded the most recent Windows drivers fo...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# 	Is it that serious?  My EKG often comes back wit...
# Predicted Category: sci.med
#
# Document:
# Considering that Clinton received a draft notice ...
# Predicted Category: talk.politics.misc
#
# Document: From article <1qvgu5INN2np@lynx.unm.edu>, by osins...
# Predicted Category: sci.med
#
# Document: Since someone brought up sports radio, howabout sp...
# Predicted Category: rec.sport.hockey
#
# Document:
# Great start.  I realize immediately that you are ...
# Predicted Category: alt.atheism
#
# Document: I have replaced the osz to 66 MHz yesterday and no...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Having run completely out of time, I've got to get...
# Predicted Category: rec.sport.baseball
#
# Document: Hi there again...
# I still have a few tapes left......
# Predicted Category: misc.forsale
#
# Document: Not to be too snide about it, but I think this Chr...
# Predicted Category: soc.religion.christian
#
# Document:
#
# Roberts played in last night game against the Sh...
# Predicted Category: rec.sport.hockey
#
# Document: Hi netters,
#
# Does anyone know have any info on the...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I'm making a customized paint program in DOS and n...
# Predicted Category: comp.graphics
#
# Document:
# Better still, years ago they demonstrated a cold ...
# Predicted Category: sci.space
#
# Document:
#
# Yep.  There's truth in all those religions, even...
# Predicted Category: alt.atheism
#
# Document:
#
# Which listsev was this and is the discussion sti...
# Predicted Category: sci.med
#
# Document: In the mist of the Rangers soap box (i.e. Captain ...
# Predicted Category: rec.sport.hockey
#
# Document:
#
#
#
# Let me salute Gary Chin for speaking the gospe...
# Predicted Category: soc.religion.christian
#
# Document:
# Hello net.  I have a 386sx motherboard with the P...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: This will be the first of monthly postings of the ...
# Predicted Category: sci.med
#
# Document: I know that there is MSG sensitivity.  When I eat ...
# Predicted Category: sci.med
#
# Document: GB> From: geb@cs.pitt.edu (Gordon Banks)
# GB> >(I a...
# Predicted Category: sci.med
#
# Document: I need the file format for cc:Mail file formats - ...
# Predicted Category: comp.graphics
#
# Document:
# He's not gone yet.  The position opening is down ...
# Predicted Category: rec.sport.hockey
#
# Document:
# ...
# Predicted Category: rec.autos
#
# Document:
#
#
# Now you are actually claiming that 2,000,000 Mu...
# Predicted Category: talk.politics.mideast
#
# Document:
#
# It is kind of absurd, isn't it?  Some players ev...
# Predicted Category: sci.space
#
# Document:
# Speaking of spelling errors on the Cup, I wonder ...
# Predicted Category: rec.sport.hockey
#
# Document: 1st round:
# ----------
#
# ...
#
# Document:
# In order to emit blue light, a semiconductor must...
# Predicted Category: sci.electronics
#
# Document:
# You should realize that form letters are the *wor...
# Predicted Category: sci.crypt
#
# Document: The 200CD is one of three oscillators that HP made...
# Predicted Category: sci.electronics
#
# Document:
#
#
# 					Pardon me, a humble atheist, but exactly w...
# Predicted Category: soc.religion.christian
#
# Document:
# Here are some selected excerpts of the invitation...
# Predicted Category: sci.space
#
# Document:
#
#
#
# I've been watching & playing hockey for a good...
# Predicted Category: rec.sport.hockey
#
# Document:
# ------------ Part 7 of 14 ------------
# MI:6EI:6EI...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# 	Strictly from memory, I think the Phillies were...
# Predicted Category: rec.sport.baseball
#
# Document: The word some sums it up, alot of scientist have c...
# Predicted Category: sci.space
#
# Document: You could argue that if you wanted, but I think a ...
# Predicted Category: soc.religion.christian
#
# Document:
# So when they took the time to *copy* *the* *text*...
# Predicted Category: sci.electronics
#
# Document: BLUES PLAYOFF SCORING THROUGH END OF NORRIS SEMIFI...
# Predicted Category: rec.sport.hockey
#
# Document: agencies
# your
# dictionary
#
# I don't recall say...
# Predicted Category: talk.politics.guns
#
# Document:
#
# IMHO, encryption is (also) protected under the S...
# Predicted Category: sci.crypt
#
# Document:
#
#
#
# Is this still in print or available (other tha...
# Predicted Category: sci.space
#
# Document:
# Let's assume, for the moment, that the system rea...
# Predicted Category: sci.crypt
#
# Document:
# Might be a good idea...  The resolution you reque...
# Predicted Category: sci.electronics
#
# Document: I agree! Rob Shick sucks big time.  He did the sam...
# Predicted Category: rec.sport.hockey
#
# Document:
# You are in the village. Many happy returns! Be se...
# Predicted Category: rec.motorcycles
#
# Document: In <1r1d2r$baf@umcc.umcc.umich.edu> dlc@umcc.umcc....
# Predicted Category: misc.forsale
#
# Document:
#
# The flushing is due to vascular dilation, part o...
# Predicted Category: sci.med
#
# Document: How about 250MB/s for 64-bit VLB or 350MB/s for Qu...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# : > > However, legalizing it and just sticking so...
# Predicted Category: talk.politics.misc
#
# Document:
# The danger in philosophizing about science is tha...
# Predicted Category: sci.med
#
# Document:
#
# No, Bobby.  Stalin killed millions in the name o...
# Predicted Category: alt.atheism
#
# Document:
#
# Come again? The image-conscious Armenians sorely...
# Predicted Category: talk.politics.mideast
#
# Document: I agree. It was great for the ESPN people to show ...
# Predicted Category: rec.sport.hockey
#
# Document: : >What does a 200-400 meg 5 megs/sec SCSI drive c...
# Predicted Category: comp.sys.mac.hardware
#
# Document:   > anybody know the difference between the Quarda...
# Predicted Category: comp.sys.mac.hardware
#
# Document: I need to sell the following items:
#
# an Apple IIe ...
# Predicted Category: misc.forsale
#
# Document: #Tells you something about the fascist politics be...
# Predicted Category: rec.motorcycles
#
# Document:
# You've asked a toughie of a question.  There are ...
# Predicted Category: sci.med
#
# Document:
#
#   Lawson was on the Yamaha.
#
# Not taking anything...
# Predicted Category: rec.motorcycles
#
# Document: Hello there,
#
# I am looking for Sim City for PC (ne...
# Predicted Category: misc.forsale
#
# Document: We have been using Iterated Systems compression bo...
# Predicted Category: comp.graphics
#
# Document: I know that alot of how people think and act in a ...
# Predicted Category: sci.space
#
# Document: Looking for PostScript or Tex version of a paper c...
# Predicted Category: sci.crypt
#
# Document: This might a real wierd idea or maybe not..
#
# I hav...
# Predicted Category: sci.space
#
# Document:
# [and quotes a lot of stuff unnecessarily]
#
#
#
# Ain'...
# Predicted Category: talk.politics.guns
#
# Document: [reply to Daniel.Prince@f129.n102.z1.calcom.socal....
# Predicted Category: sci.med
#
# Document: Archive-Name: rec-autos/part2
#
# Automotive Mailing ...
# Predicted Category: misc.forsale
#
# Document: Hello
#
# I've got an old Trident 8800CS SVGA card, b...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
# Say, you bought your Saturn at $13k, with a deal...
# Predicted Category: rec.autos
#
# Document: It depends. If, in the judgment of the umpire the ...
# Predicted Category: rec.sport.baseball
#
# Document:
#
#
#
# Yup.  I can hear the _millions_ cheering for D...
# Predicted Category: rec.motorcycles
#
# Document:   HELP!
# Maybe anybody know names of conferences in...
# Predicted Category: sci.med
#
# Document: Yesterday, a friend had asked me to accompany him ...
# Predicted Category: rec.motorcycles
#
# Document:
# What is "doing it right the first time"?  Murdere...
# Predicted Category: talk.politics.guns
#
# Document:
#
# But why do you characterize this as a "flight of...
# Predicted Category: sci.space
#
# Document: Accounts of Anti-Armenian Human Right Violations i...
# Predicted Category: talk.politics.mideast
#
# Document: # #  "Abortions destructive of the fetus must be p...
# Predicted Category: talk.politics.misc
#
# Document:
# This is the case in Britain, according to the hea...
# Predicted Category: sci.crypt
#
# Document: Hi:
# On the 1024x768x256 mode, the font sizes of Wi...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: Here is the MacWeek article describing the DUO ram...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# Kelly Kisio was the captain of the Rangers when ...
# Predicted Category: rec.sport.hockey
#
# Document:
# : 09.05.93, 14:48
#
# : Hi out there !
#
# : Is there a...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: ...
# Predicted Category: rec.autos
#
# Document: {drinking & riding}
#
# 0.20 is DWI in New York?  Her...
# Predicted Category: rec.motorcycles
#
# Document:
#
#
# I'm sure there are many people who work with ne...
# Predicted Category: comp.graphics
#
# Document: Believe it or not, we DO have phone books, but the...
# Predicted Category: sci.electronics
#
# Document: I'd like to thank everyone who took the time to re...
# Predicted Category: talk.politics.guns
#
# Document:
# Theoretically supposed to be reduced.... not any ...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
#
# Tell me, 'kmagnacca', were you high on 'Arromdi...
# Predicted Category: talk.politics.mideast
#
# Document: I am looking at buying a Dual Sport type motorcycl...
# Predicted Category: rec.motorcycles
#
# Document:
# You obviously did not watch the Twins in Chicago....
# Predicted Category: rec.motorcycles
#
# Document:
# In the kind I have made I used a Lite sour cream ...
# Predicted Category: sci.med
#
# Document:
#
#
#
# Well, I think that most Christians believe tha...
# Predicted Category: sci.med
#
# Document: WHile we are on the subject of the shuttle softwar...
# Predicted Category: sci.space
#
# Document:
# Microsoft has a division called Microsoft Consult...
# Predicted Category: sci.electronics
#
# Document: Can people please stop the 'I think/know the BATF/...
# Predicted Category: talk.politics.misc
#
# Document: I have just noticed my FileManager doing something...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: So it looks like I'm going to have to put a couple...
# Predicted Category: sci.electronics
#
# Document:
# To avoid paperwork associated with re-certificati...
# Predicted Category: misc.forsale
#
# Document:
#
# But, the goal need not be a subjective one.  For...
# Predicted Category: alt.atheism
#
# Document: The best group to keep you informed is the Crohn's...
# Predicted Category: sci.med
#
# Document:
#
# Yes, but then someone would have no problem drai...
# Predicted Category: rec.autos
#
# Document: THE WHITE HOUSE
#
#                     Office of the...
# Predicted Category: talk.politics.misc
#
# Document: What 4 or more com port boards are available for P...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# Of all the stupid postings you've brought here re...
# Predicted Category: talk.politics.mideast
#
# Document: ......
# Predicted Category: rec.autos
#
# Document: I do not have this type of problem, but at one poi...
# Predicted Category: comp.sys.mac.hardware
#
# Document: Hi all,
# Of late my computer's Power supply fan has...
# Predicted Category: sci.electronics
#
# Document:
# Yes, I did punch in the wrong numbers (working to...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I have come across what I consider to be an excell...
# Predicted Category: soc.religion.christian
#
# Document:
#
# Yep, it's called OS2!
# ...
# Predicted Category: rec.motorcycles
#
# Document:
#
#     The lethality in small part, but mostly what...
# Predicted Category: soc.religion.christian
#
# Document:
#
#
#
#
#
# If I recall correctly, the bill would provid...
# Predicted Category: talk.politics.guns
#
# Document: I have a question about tires for my Guzzi. It is ...
# Predicted Category: rec.motorcycles
#
# Document:
# Yes it invokes the associated application. That t...
# Predicted Category: rec.motorcycles
#
# Document: I would appreciate it if someone could volunteer t...
# Predicted Category: rec.sport.hockey
#
# Document: From article <C5wDMK.Jrn@hawk.cs.ukans.edu>, by 3s...
# Predicted Category: comp.sys.mac.hardware
#
# Document: I have one of those HEAVY antique upright pianos I...
# Predicted Category: misc.forsale
#
# Document:
# Do you have a basis for this claim?  Try these st...
# Predicted Category: rec.sport.hockey
#
# Document:
#   For a commerical package try WAVE from  Precisi...
# Predicted Category: comp.graphics
#
# Document: The subject says it all. I bought Adobe Type Manag...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
# I've been wondering about this myself.  The house...
# Predicted Category: sci.med
#
# Document: Hello,
# I have a Hayes 9600 moden with no cables o...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: The article that follows was taken from the Wednes...
# Predicted Category: talk.politics.misc
#
# Document: Please could someone in the US give me the current...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# Dennis, I'm astounded. I didn't know you were int...
# Predicted Category: talk.religion.misc
#
# Document:
# I can only say that those people are wrong. The w...
# Predicted Category: talk.politics.misc
#
# Document: This was in Wed. WSJ.
#
# [start]
# The white house, se...
# Predicted Category: talk.politics.misc
#
# Document: ...
# Predicted Category: rec.autos
#
# Document: Here is the OPI (Offensive Production Index) for a...
# Predicted Category: rec.sport.baseball
#
# Document: Here is a list I get when I was combing through so...
# Predicted Category: sci.electronics
#
# Document: Long time, no see.
#
# 			Andreas
#
# --
#
# 		Andreas - S...
# Predicted Category: rec.motorcycles
#
# Document: #
# #                        A ...
# Predicted Category: sci.space
#
# Document:
# Wrong.
#
#
# Quite true. And evolution made "decided"...
# Predicted Category: alt.atheism
#
# Document: ULTRIX/X11R4 to plot surfaces and contour plots fr...
# Predicted Category: comp.windows.x
#
# Document: I remember reading about a program that made windo...
# Predicted Category: comp.os.ms-windows.misc
#
# Document: I own a Zoom V.32bis modem and I am having some st...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: Forwarded from the Mars Observer Project
#
#         ...
# Predicted Category: sci.space
#
# Document:   I'm interested in a center channel for my home t...
# Predicted Category: misc.forsale
#
# Document:
#
# 	Okay, I went back and looked:  sure enough, my ...
# Predicted Category: rec.motorcycles
#
# Document: All,
#
# During my attempts to find out how the AT ha...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: If you're willing to do a little work, you can mak...
# Predicted Category: comp.windows.x
#
# Document:
# Huh?...
# Predicted Category: rec.motorcycles
#
# Document: Dear friends,
#
# I am a graduate student in Educatio...
# Predicted Category: sci.med
#
# Document: I have an unopened CD called "Bird-The Original Re...
# Predicted Category: misc.forsale
#
# Document: We have a LAN where we are doing development on pr...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
#
# Yes, that's him.  Was I not specific enough?
#
# Ju...
# Predicted Category: rec.sport.baseball
#
# Document:
# Good point. Not only baseball but local NBA baske...
# Predicted Category: rec.sport.hockey
#
# Document:
# Both protests would be denied, of course.  The um...
# Predicted Category: rec.sport.baseball
#
# Document: We are interested in constructing a reentry vehicl...
# Predicted Category: sci.space
#
# Document: The Waco Quiz
#
# What would you do in the following ...
# Predicted Category: talk.politics.guns
#
# Document: Hello, I'm doing a paper on censorship in music an...
# Predicted Category: talk.politics.misc
#
# Document:
# Most likely the tragic situation in Bosnia is a c...
# Predicted Category: alt.atheism
#
# Document: from alt.law-enforcement
#
#
#
#
#
#
# -- ...
# Predicted Category: talk.politics.guns
#
# Document: ha... all this talk about changing the clock speed...
# Predicted Category: comp.sys.mac.hardware
#
# Document: How much better to get wisdom than gold, to choose...
# Predicted Category: sci.space
#
# Document: I only caught the tail end of this one on ESPN.  D...
# Predicted Category: sci.electronics
#
# Document:
#
# Done. But did it change the fact that during the...
# Predicted Category: talk.politics.mideast
#
# Document:                               ^^^^^^
#              ...
# Predicted Category: rec.motorcycles
#
# Document: Hi folks,
#
# At the end of the summer I'm planning o...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: deleted...
# Predicted Category: rec.autos
#
# Document:          Is it realistic for the government to try...
# Predicted Category: sci.crypt
#
# Document: Anyone out there in netland have a spare data pod ...
# Predicted Category: sci.electronics
#
# Document: On Sat, 17 Apr 1993 20:42:58 GMT, Greg Hennessy ob...
# Predicted Category: talk.politics.misc
#
# Document: : I have a 486DX-33 computer with a SoundBlaster 1...
# Predicted Category: comp.os.ms-windows.misc
#
# Document:
#
#
#
#
# ...
# Predicted Category: rec.autos
#
# Document: OFM responds to a query about reference works:
#
#   ...
# Predicted Category: soc.religion.christian
#
# Document:
# Ok.  I have a record that shows a IIsi with and w...
# Predicted Category: comp.sys.mac.hardware
#
# Document:
# Here are a few ideas:
#
# 1) a free library card so ...
# Predicted Category: talk.politics.guns
#
# Document:
#
#
# Only because you are apparently easy to fool.  ...
# Predicted Category: sci.space
#
# Document:
# Blood glucose levels of 40 or so are common sever...
# Predicted Category: sci.med
#
# Document: I went to Staples in Framingham, MA, today, and gr...
# Predicted Category: misc.forsale
#
# Document: } >I'd have to say the most impressive HRs I've ev...
# Predicted Category: rec.sport.baseball
#
# Document: What's the difference between a 16550 UART and a 1...
# Predicted Category: rec.motorcycles
#
# Document: does anybody have any info on this monitor or the ...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: I would like to program Tseng ET4000 to nonstandar...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document:
# are you sure 45g is the right number? as far as i...
# Predicted Category: sci.electronics
#
# Document: ...
# Predicted Category: rec.autos
#
# Document:
#
# I have tried others, but I think that the Adapte...
# Predicted Category: comp.sys.ibm.pc.hardware
#
# Document: Hello everyone.
#
# Last week I posted a similar ques...
# Predicted Category: soc.religion.christian
#
# Document: A little correction on my previous post about an h...
# Predicted Category: sci.electronics
#
# Document:
# How can you be sure the two visitors were really ...
# Predicted Category: sci.crypt
#
# Document: I am doing a report on the topic of 'Advanced Memo...
# Predicted Category: comp.graphics
#
# Document:
# (deletion)...
# Predicted Category: alt.atheism
#
# Document:
# <Moral Driver distinctions deleted>
#
#
# Compare the...
# Predicted Category: alt.atheism
#
# Document:
#
# big Capacitor :-)   Real Big  capacitor....
# Predicted Category: sci.electronics

# %% [markdown]
# #
